# %%
import pandas as pd
import os

# %%
df = pd.read_csv("C:/Users/asus/OneDrive/Desktop/Pandas-Data-Science-Tasks-master/SalesAnalysis/Sales_Data/Sales_April_2019.csv")

# %%
df.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1      NaN                         NaN              NaN        NaN
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1             NaN                                   NaN
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001

# %% [markdown]
# #### Now Concating 12 Months of data All the csv file into One.

# %%
files = [file for file in os.listdir("C:/Users/asus/OneDrive/Desktop/Pandas-Data-Science-Tasks-master/SalesAnalysis/Sales_Data")]
all_months_data = pd.DataFrame()
for file in files:
    df = pd.read_csv("C:/Users/asus/OneDrive/Desktop/Pandas-Data-Science-Tasks-master/SalesAnalysis/Sales_Data/"+file)
    all_months_data = pd.concat([all_months_data,df])
all_months_data.to_csv("all_data.csv",index=False)

# %%
all_data = pd.read_csv("all_data.csv")
all_data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1      NaN                         NaN              NaN        NaN
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1             NaN                                   NaN
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001

# %% [markdown]
# #### In above data we see NaN values which needs to be removed before proceeding

# %%
nan_df = all_data[all_data.isna().any(axis=1)]
nan_df.head()
# Out:
#      Order ID Product Quantity Ordered Price Each Order Date Purchase Address
# 1         NaN     NaN              NaN        NaN        NaN              NaN
# 356       NaN     NaN              NaN        NaN        NaN              NaN
# 735       NaN     NaN              NaN        NaN        NaN              NaN
# 1433      NaN     NaN              NaN        NaN        NaN              NaN
# 1553      NaN     NaN              NaN        NaN        NaN              NaN

# %%
all_data = all_data.dropna(how='all')
all_data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
# 5   176561            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001

# %% [markdown]
# #### Creating a seperating Month column

# %%
all_data['Month'] = all_data['Order Date'].str[0:2]
all_data['Month'] = all_data['Month'].astype('int32')
all_data.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 2
#       1 all_data['Month'] = all_data['Order Date'].str[0:2]
# ----> 2 all_data['Month'] = all_data['Month'].astype('int32')
#       3 all_data.head()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6534, in NDFrame.astype(self, dtype, copy, errors)
#    6530     results = [ser.astype(dtype, copy=copy) for _, ser in self.items()]
#    6532 else:
#    6533     # else, only a single dtype is given
# -> 6534     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6535     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6536     return res.__finalize__(self, method="astype")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:414, in BaseBlockManager.astype(self, dtype, copy, errors)
#     411 elif using_copy_on_write():
# ...

# %% [markdown]
# #### Error: ValueError: invalid literal for int() with base 10: 'Or' found this value in column.

# %% [markdown]
# #### Removing The values

# %% [markdown]
# #### filtering the data

# %%
all_data = all_data[all_data['Order Date'].str[0:2]!='Or']
all_data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
# 5   176561            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address Month
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001    04
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215    04
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001    04
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001    04
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001    04

# %% [markdown]
# #### Question 1: Which Month Has the Highest Sales and How was Earned That Month?

# %% [markdown]
# #### For This We will make a new column of sales = [Quantity]*[price]

# %%
all_data['Sales'] = all_data['Quantity Ordered']*all_data['Price Each']
all_data.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\ops\array_ops.py:220, in _na_arithmetic_op(left, right, op, is_cmp)
#     219 try:
# --> 220     result = func(left, right)
#     221 except TypeError:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\computation\expressions.py:242, in evaluate(op, a, b, use_numexpr)
#     240     if use_numexpr:
#     241         # error: "None" not callable
# --> 242         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     243 return _evaluate_standard(op, op_str, a, b)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\computation\expressions.py:131, in _evaluate_numexpr(op, op_str, a, b)
#     130 if result is None:
# --> 131     result = _evaluate_standard(op, op_str, a, b)
#     133 return result
#
# ...

# %% [markdown]
# #### TypeError: can't multiply sequence by non-int of type 'str'
# #### Datatype of both column are different so first we have to chage the data type of both

# %%
all_data['Quantity Ordered'] = pd.to_numeric(all_data['Quantity Ordered'])
all_data['Price Each']       = pd.to_numeric(all_data['Price Each'])

# %% [markdown]
# #### Making a sales Column Again With Correct data Types

# %%
all_data['Sales'] = all_data['Quantity Ordered']*all_data['Price Each']
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#        Order Date                      Purchase Address Month   Sales
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001    04   23.90
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215    04   99.99
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001    04  600.00
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001    04   11.99
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001    04   11.99

# %% [markdown]
# #### Back to Question 1:
# #### Which Months has the highest sales and by howMuch

# %% [markdown]
# #### This is achieved By Group By month

# %%
all_data.groupby('Month').sum()
# Out:
#                                                 Order ID  \
# Month
# 01     2971502978172978172979692983442990492991253003...
# 02     1505021505031505041505051505061505071505081505...
# 03     1505331505411508121517491520361532841535441538...
# 04     1765581765591765601765601765611765621765631765...
# 05     1769781775511777781777781790761790761791341800...
# 06     2099212099222099232099242099252099262099272099...
# 07     2229102229112229122229132229142229152229162229...
# 08     2366702366712366722366732366742366752366762366...
# 09     2388342392852406362410542423432428652436672449...
# 10     2593582593592593602593612593622593632593642593...
# 11     2787972787982787992788002788012788022788032788...
# 12     2956652956662956672956682956692956702956712956...
#
#                                                  Product  Quantity Ordered  \
# Month
# 01     Lightning Charging CableiPhoneLightning Chargi...             10903
# ...

# %% [markdown]
# #### Visualizing data with Matplotlib

# %% [markdown]
# #### Why?
# #### As Reading or Understaing text data in rows and columns does not provide quick insights

# %%
import matplotlib.pyplot as plt
result = all_data.groupby('Month').sum()
Months = range(1,13)
plt.bar(Months,result['Sales'])
plt.xticks(Months)
plt.xlabel("Months")
plt.ylabel("Sales in USD$")
plt.show()

# %% [markdown]
# #### Question 2: Which city has highest Number of sales

# %% [markdown]
# #### to achieve this we need a city column

# %% [markdown]
# #### Addding A City Column

# %% [markdown]
# #### we will use apply function of pandas which helps us to apply any function that we made

# %%
def get_city(address):
    return address.split(",")[1]
all_data["City"] = all_data['Purchase Address'].apply(lambda x:get_city(x))
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#        Order Date                      Purchase Address Month   Sales  \
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001    04   23.90
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215    04   99.99
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001    04  600.00
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001    04   11.99
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001    04   11.99
#
#            City
# 0        Dallas
# 2        Boston
# 3   Los Angeles
# 4   Los Angeles
# 5   Los Angeles

# %% [markdown]
# #### we have city and now we will again do group by by city
# #### Back to  Question 2:

# %% [markdown]
# #### We do got the city column but many parts of the world has duplicated city so we need to have its state as well

# %% [markdown]
# #### To get the state

# %%
def get_state(address):
    return address.split(",")[2].split(" ")[1]
def get_city(address):
    return address.split(",")[1]
all_data["City"] = all_data['Purchase Address'].apply(lambda x:f"{get_city(x)}({get_state(x)})")
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#        Order Date                      Purchase Address Month   Sales  \
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001    04   23.90
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215    04   99.99
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001    04  600.00
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001    04   11.99
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001    04   11.99
#
#                City
# 0        Dallas(TX)
# 2        Boston(MA)
# 3   Los Angeles(CA)
# 4   Los Angeles(CA)
# 5   Los Angeles(CA)

# %% [markdown]
# #### Back TO question 2

# %%
result = all_data.groupby('City').sum()
result.head()
# Out:
#                                                            Order ID  \
# City
#  Atlanta(GA)      1765641765711765821765891766231766271766341766...
#  Austin(TX)       1765911766091766741766771766861767011767051767...
#  Boston(MA)       1765591765661765781765811765851765851766001766...
#  Dallas(TX)       1765581765691765701765771765961766021766101766...
#  Los Angeles(CA)  1765601765601765611765671765741765741765761765...
#
#                                                             Product  \
# City
#  Atlanta(GA)      USB-C Charging CableLightning Charging CableBo...
#  Austin(TX)       Apple Airpods HeadphonesApple Airpods Headphon...
#  Boston(MA)       Bose SoundSport HeadphonesWired HeadphonesAppl...
#  Dallas(TX)       USB-C Charging Cable27in 4K Gaming MonitorAA B...
#  Los Angeles(CA)  Google PhoneWired HeadphonesWired HeadphonesGo...
#
#                   Quantity Ordered  Price Each  \
# City
#  Atlanta(GA)                 16602  2779908.20
# ...

# %%
import matplotlib.pyplot as plt
cities = [city for city,df in all_data.groupby('City')]
result = all_data.groupby('City').sum()
plt.bar(cities,result['Sales'])
plt.xticks(cities,rotation='vertical',size=8)
plt.xlabel("Cities")
plt.ylabel("Sales in USD$")
plt.show()

# %% [markdown]
# #### Question 3: At what time should we display advertisement to maximise livelihood of Costumers's buyig products

# %%
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#        Order Date                      Purchase Address Month   Sales  \
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001    04   23.90
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215    04   99.99
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001    04  600.00
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001    04   11.99
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001    04   11.99
#
#                City
# 0        Dallas(TX)
# 2        Boston(MA)
# 3   Los Angeles(CA)
# 4   Los Angeles(CA)
# 5   Los Angeles(CA)

# %% [markdown]
# #### To achieve this we will work with order date column and sales column

# %% [markdown]
# #### we will use date-time library
# #### we will convert this our standard date time

# %%
all_data['Order Date'] = pd.to_datetime(all_data['Order Date'], format='%Y-%m-%d %H:%M:%S')

# %%
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address Month   Sales  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001    04   23.90
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215    04   99.99
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001    04  600.00
# 4 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001    04   11.99
# 5 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001    04   11.99
#
#                City
# 0        Dallas(TX)
# 2        Boston(MA)
# 3   Los Angeles(CA)
# ...

# %% [markdown]
# #### Making Hour Column ANd minute column

# %%
all_data['Hour'] = all_data['Order Date'].dt.hour
all_data['Minute'] = all_data['Order Date'].dt.minute

# %%
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address Month   Sales  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001    04   23.90
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215    04   99.99
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001    04  600.00
# 4 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001    04   11.99
# 5 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001    04   11.99
#
#                City  Hour  Minute
# 0        Dallas(TX)     8      46
# 2        Boston(MA)    22      30
# ...

# %% [markdown]
# #### the above data frame has a new rows named Hour and Minutes

# %% [markdown]
# #### Now We will Group By and Plot Some stuff

# %%
hours = [hour for hour,df in all_data.groupby('Hour')]
plt.plot(hours,all_data.groupby('Hour').count())
plt.xticks(hours)
plt.xlabel("Hours --> ")
plt.ylabel("No of Orders")
plt.grid()
plt.show()

# %% [markdown]
# #### Question 4?
# #### What products are most often sold together?

# %%
all_data.head(10)
# Out:
#    Order ID                     Product  Quantity Ordered  Price Each  \
# 0    176558        USB-C Charging Cable                 2       11.95
# 2    176559  Bose SoundSport Headphones                 1       99.99
# 3    176560                Google Phone                 1      600.00
# 4    176560            Wired Headphones                 1       11.99
# 5    176561            Wired Headphones                 1       11.99
# 6    176562        USB-C Charging Cable                 1       11.95
# 7    176563  Bose SoundSport Headphones                 1       99.99
# 8    176564        USB-C Charging Cable                 1       11.95
# 9    176565          Macbook Pro Laptop                 1     1700.00
# 10   176566            Wired Headphones                 1       11.99
#
#             Order Date                        Purchase Address Month    Sales  \
# 0  2019-04-19 08:46:00            917 1st St, Dallas, TX 75001    04    23.90
# ...

# %% [markdown]
# #### From The above data we can check that order id of two product is same it means order are sold together

# %% [markdown]
# #### To achieve ww will make a new dataframe and will save the duplicated values in it

# %%
df = all_data[all_data['Order ID'].duplicated(keep=False)]
df['Grouped']  = df.groupby('Order ID')['Product'].transform(lambda x:','.join(x))
df.head()
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_3352\4188646141.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Grouped']  = df.groupby('Order ID')['Product'].transform(lambda x:','.join(x))
#    Order ID                     Product  Quantity Ordered  Price Each  \
# 3    176560                Google Phone                 1      600.00
# 4    176560            Wired Headphones                 1       11.99
# 18   176574                Google Phone                 1      600.00
# 19   176574        USB-C Charging Cable                 1       11.95
# 30   176585  Bose SoundSport Headphones                 1       99.99
#
#             Order Date                      Purchase Address Month   Sales  \
# ...

# %% [markdown]
# #### WE have Duplicated Values which can be Dropped

# %%
df = df[['Order ID','Grouped']].drop_duplicates()
df.head()
# Out:
#     Order ID                                            Grouped
# 3     176560                      Google Phone,Wired Headphones
# 18    176574                  Google Phone,USB-C Charging Cable
# 30    176585  Bose SoundSport Headphones,Bose SoundSport Hea...
# 32    176586                AAA Batteries (4-pack),Google Phone
# 119   176672      Lightning Charging Cable,USB-C Charging Cable

# %% [markdown]
# #### We can also seperate all values from it and get exact values of products sold the most but this solution do complete our Quesion

# %% [markdown]
# #### Question 5: what products are sold the most and why do you think they are sold the Most?

# %%
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address Month   Sales  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001    04   23.90
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215    04   99.99
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001    04  600.00
# 4 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001    04   11.99
# 5 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001    04   11.99
#
#                City  Hour  Minute
# 0        Dallas(TX)     8      46
# 2        Boston(MA)    22      30
# ...

# %%
product_group = all_data.groupby('Product')
product_group.sum()['Quantity Ordered']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[66], line 2
#       1 product_group = all_data.groupby('Product')
# ----> 2 product_group.sum()['Quantity Ordered']
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:3063, in GroupBy.sum(self, numeric_only, min_count, engine, engine_kwargs)
#    3058 else:
#    3059     # If we are grouping on categoricals we want unobserved categories to
#    3060     # return zero, rather than the default of NaN which the reindexing in
#    3061     # _agg_general() returns. GH #31422
#    3062     with com.temp_setattr(self, "observed", True):
# -> 3063         result = self._agg_general(
#    3064             numeric_only=numeric_only,
#    3065             min_count=min_count,
#    3066             alias="sum",
#    3067             npfunc=np.sum,
#    3068         )
# ...

# %% [markdown]
# #### Here We Will Drop DateTIme Column

# %%
all_data = all_data.drop('Order Date', axis=1)

# %%
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#                        Purchase Address Month   Sales              City  Hour  \
# 0          917 1st St, Dallas, TX 75001    04   23.90        Dallas(TX)     8
# 2     682 Chestnut St, Boston, MA 02215    04   99.99        Boston(MA)    22
# 3  669 Spruce St, Los Angeles, CA 90001    04  600.00   Los Angeles(CA)    14
# 4  669 Spruce St, Los Angeles, CA 90001    04   11.99   Los Angeles(CA)    14
# 5     333 8th St, Los Angeles, CA 90001    04   11.99   Los Angeles(CA)     9
#
#    Minute
# 0      46
# 2      30
# 3      38
# 4      38
# 5      27

# %%
product_group = all_data.groupby('Product')
Quantity_Ordered = product_group.sum()['Quantity Ordered']
# Out:
# Product
# 20in Monitor                   4129
# 27in 4K Gaming Monitor         6244
# 27in FHD Monitor               7550
# 34in Ultrawide Monitor         6199
# AA Batteries (4-pack)         27635
# AAA Batteries (4-pack)        31017
# Apple Airpods Headphones      15661
# Bose SoundSport Headphones    13457
# Flatscreen TV                  4819
# Google Phone                   5532
# LG Dryer                        646
# LG Washing Machine              666
# Lightning Charging Cable      23217
# Macbook Pro Laptop             4728
# ThinkPad Laptop                4130
# USB-C Charging Cable          23975
# Vareebadd Phone                2068
# Wired Headphones              20557
# iPhone                         6849
# Name: Quantity Ordered, dtype: int64

# %% [markdown]
# #### Plotting Then data

# %%
product_group = all_data.groupby('Product')
Quantity_Ordered = product_group.sum()['Quantity Ordered']
products = [products for products,df in product_group]
plt.bar(products,Quantity_Ordered )
plt.xlabel("Quantity Ordered")
plt.ylabel("Products")
plt.xticks(products,rotation='vertical',size=8)
plt.show()

# %% [markdown]
# #### Soltion to Question 5:
# #### Products which are sold most is
# ###                                  1. AAA batteries
# ####                                 2. Lightning Charger Cable
# ####                                 3. USB - C charging cable
# #### Reason Being they are highly sold is because they are cheap
# #### To prove this hypothesis we need to plot a price graph on the bargraph which can be done usng matplotlib
